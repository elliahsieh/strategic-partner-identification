# %% [markdown]
# Found data under 'OTHER' in 'Interventions' have been largely misclassified. Adjust manually.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/ellia.hsieh/Documents/GitHub/strategic-partner-identification/data/02-processed/processed-sleep-apnea.csv')

# %%
intv_types_exploded = df['Intervention Types'].str.split(', ').explode()
intv_types_counts = intv_types_exploded.value_counts(ascending=False)

print(intv_types_counts) # clinical trials numbers for each interverence
# Out:
# Intervention Types
# DEVICE                 919
# DRUG                   309
# OTHER                  246
# BEHAVIORAL             222
# PROCEDURE              168
# DIAGNOSTIC_TEST         88
# DIETARY_SUPPLEMENT      12
# COMBINATION_PRODUCT      6
# BIOLOGICAL               3
# RADIATION                1
# GENETIC                  1
# Name: count, dtype: int64

# %%
# See what's classified as 'OTHER'

# Set display options to show all rows

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_colwidth', None)  # Show full column width

df[df['Intervention Types'].str.contains('OTHER')]['Interventions'].str.extract(r'OTHER:\s*([^|]+)')
# Out:
#                                                                                                              0
# 6                                                                                                      placebo
# 12                                                                                                     Placebo
# 34                                                                                       Standard care for OSA
# 42                                                                                         Resistance training
# 45                                                                                                    Training
# 47                                                                                           Sound stimulation
# 50                                                                                            Standard of Care
# 55                                                                              Administration of gas mixtures
# 56                                                                                Induction of flow limitation
# 57                                                                                      Induced central apneas
# 73                                                                                               OSA-18 Survey
# 77                                                                                     SAM Clinic Intervention
# 78                                                                                    screening of sleep apnea
# 79                                                                                                  Usual Care
# 84                                                                                         Supplemental Oxygen
# 91                                                                                              computer model
# 100                                                                     Clinical nurse (supernurse) evaluation
# 104                                                                                     Conventional treatment
# 109                                                                                        didgeridoo practice
# 117                                                                                    Diagnosis of acromegaly
# 128                                                                                                   Training
# 134                                                                                                 prevention
# 148                                                                                                    Control
# 154                                                                                                       Sham
# 159                                                                                          Videoconsultation
# 167                                                                              Primary Care-based management
# 176                                                                     different treatment modalities for OSA
# 191                                                                        Moderate continuous training (MICT)
# 196                                                                                         Standard follow-up
# 199                                                                                             Carbon dioxide
# 211                                                 Ujjayi pranayama, Nadi-Shodhana pranayama, Sukha pranayama
# 218                                                                              myofunctional therapy program
# 220                                                           high intensity interval training plus myotherapy
# 221                                                                 Remotely-supervised rehabilitation program
# 228                                                            Measurement of critical airway closing pressure
# 229                                                                                                 actigraphy
# 233                                                         Inspiratory and Oropharyngeal Muscle Strengthening
# 237                                                                     Filling the Quebec Sleep Questionnaire
# 238                                                 Measurement of pharyngeal critical airway closing pressure
# 240                                                                                         Treatment as usual
# 246                                                                                              Control group
# 251                                                                                 Oral appliance plus oxygen
# 282                                                                                     Best medical treatment
# 283                                                                                     Standardized education
# 287                                                                                                         16
# 292                                                                                                    Placebo
# 294                                                                                           Early Management
# 296                                                                                          Peer-Buddy System
# 316                                                                                       the short OSAS scale
# 318                                                              Sleep endoscopy during propofol induced sleep
# 336                                                                                               no treatment
# 344                                                                                                        BLT
# 346                                                                                  Mild Intermittent Hypoxia
# 348                                                                                                 Usual Care
# 352                                                                                         Video consultation
# 360                                                                                           oral cryotherapy
# 363                                                                                      diaphragmatic release
# 376                                                                                       Detailed information
# 381                                                                                  Non-Contact Screening App
# 384                                                                                                    Placebo
# 389                                                                                        Supplemental Oxygen
# 392                                                                                Inspiratory Muscle Training
# 397                                                                                 Microcrystalline Cellulose
# 405                                                                                             Oxygen therapy
# 421                                                                                         Wave sleep surface
# 426                                                                                                TLC-Control
# 430                                                                                       Pharyngeal Manometry
# 434                                                                                                       HFNC
# 440                                                                                        Use of Nasal Lavage
# 447                                                                        Observation alone / no intervention
# 450                                                                       Inspiratory muscle strength training
# 452                                                                      Telerehabilitation solution (m-Rehab)
# 460                                                                                             Pre-natal care
# 465                                                                                                    Control
# 470                                                                                                   Room air
# 481                                                                                                 Usual Care
# 489                                                                                                  CHICA OSA
# 493                                                                                            Breathe Right ®
# 499                                                                                  Expiratory muscle trainig
# 521                                                                                          OSA questionnaire
# 523                                                                                             Rehabilitation
# 527                                                                                                    Placebo
# 530                                                                                              Sleep Symptom
# 543                                                                                                  Drive app
# 549                                                                             autonomy scale (ADL and AGGIR)
# 553                                                        Critical airway closure pressure (Pcrit) measurment
# 573                                                                                                acupuncture
# 574                                                                             CONSERVATIVE TREATMENT for OSA
# 585                                                                                            Saline infusion
# 586                                                                                               Intervention
# 599                                                                                     Conventional treatment
# 601                                                                                        Standard Care Group
# 605                                                                                        CONTROL (CON) group
# 607                       Portable (Embla Embletta X30 system and Respironic REMStar Auto M series with CFlex)
# 614                                                                                              Standard Care
# 618                                                                                         Enhanced education
# 638                                                                                     Mandibular advancement
# 644   1) hyperventilation via noninvasive positive pressure ventilation 2) multiple trials of episodic hypoxia
# 647                                                                      Screening for obstructive sleep apnea
# 654                                                                                    Obstructive sleep apnea
# 669                                                               Sleep and pulmonary physiologic measurements
# 676                                                                                              Control Group
# 686                                                                                                    Neo App
# 706                                                                                      Semi-upright position
# 708                          Subject using usual positive airway pressure therapy while sleeping for one night
# 709                                                                               Chronic Intermittent Hypoxia
# 714                                                                               Questionnaire Administration
# 717                                                                                        Educational Support
# 728                                                                        Upper airway collapsibility (Pcrit)
# 772                                                                                           medical hypnosis
# 773                                                                          Negative airway pressure delivery
# 781                                                                Divided Attention Steering Simulator (DASS)
# 792                                                                                               Experimental
# 806                                                                                   [C11]Acetate and HED PET
# 812                                                                                        Historical Controls
# 813                                                                                  CDS with Sleep Navigation
# 814                                                                                                 Didgeridoo
# 816                                                                                              Questionnaire
# 827                                                                                 Remote control of patients
# 832                                                                                            No intervention
# 834                                                                                       Usual Care (4 weeks)
# 838                                                                                           Hyperoxia/oxygen
# 847                                                                      No positive airway pressure treatment
# 854                                                                                            Nasal High Flow
# 859                                                           Therapeutic decision Infrared thermgraphy system
# 863                                                                                                     Niacin
# 865                                                                                          altitude exposure
# 877                                                                              Pharyngeal topical anesthesia
# 891                                                                                        Mindfulness Program
# 893                                                                                                    Control
# 894                                                                                                Restriction
# 897                                                                                                         TT
# 903                                                                            Hand grip isometric contraction
# 906                                                                          myeloid PTP1B expression analysis
# 912                                                                                                    Placebo
# 944                                                                                     FDA-Approved Treatment
# 947                                                                                            No nasal oxygen
# 950                                                                        Continuous Positive Airway Pressure
# 953                                                                            Measure of ODI and heart rhythm
# 968                                                                                              Standard care
# 973                                                                                    STOP-BANG Scoring Model
# 977                                                                                                        HHF
# 982                                                                                           Watchful Waiting
# 998                                                                                                 Usual Care
# 999                                                                                Inspiratory muscle training
# 1014                                                                                           Case Management
# 1016                                                                                            Placebo nozzle
# 1028                                                                                        Intervention group
# 1034                                                                                             Control Group
# 1035                                                                      Intensive decongestive physiotherapy
# 1061                                                                             Mandibular advancement device
# 1065                                                               Continuous Positive Airway Pressure Therapy
# 1068                                                                                            Speech therapy
# 1077                                                                                                 Hyperoxia
# 1083                                                                                     Tailored intervention
# 1109                                                                               LMA with modified retractor
# 1112                                                                                   Sleep hygiene education
# 1153                                                                                              Telecoaching
# 1164                                                                                             Questionnaire
# 1169                                                                                              Experimental
# 1195                                                               Evaluation of the autonomous nervous system
# 1203                                                                                                  Room Air
# 1207                                                                                      Interventional group
# 1215                                                                                    Nonsurgical management
# 1217                                                                                   Video-assisted training
# 1235                                                                                            Impedancemetry
# 1239                                                                              Positron Emission Tomography
# 1243                                                                Continuous positive airway pressure device
# 1246                                                                                     Hypercapnia treatment
# 1252                                                                                              Telemedicine
# 1262                                                                                Smartphone application use
# 1273                                                               AF standard management and OSA general care
# 1288                                                                       Morphine pharmacokinetic evaluation
# 1290                                                                                    conservative treatment
# 1293                                                                                             Sleep testing
# 1295                                                                                                Usual care
# 1296                                                                                   Neurocognitive function
# 1307                                                                                           home sleep test
# 1319                                                                            Laryngopharyngeal sensory test
# 1326                                                                                             Standard care
# 1329                                                                          training and educational program
# 1330                                                                                                   Control
# 1331                                                                                 Mild intermittent hypoxia
# 1350                                                                                               study group
# 1352                                                                                                   Placebo
# 1358                                                            ASAP Intervention Quality Improvement Protocol
# 1377                                                                                          Hypoxic exposure
# 1392                                                           Hyperoxic Hypercapnic Ventilatory Response Test
# 1402                                                                                              Care pathway
# 1413                                                                                     Myofunctional Therapy
# 1418                                                                     High flow nasal cannula therapy group
# 1423                                                                  Evaluation by Sleep Medicine Specialists
# 1424                                                                         No preventive oxygen therapy (2L)
# 1426                                                                                              Decision aid
# 1432                                                                               Inspiratory Muscle Training
# 1434                                                            to explore the severity of NAC in case of OSAS
# 1447                                                                                  Standard Medical Therapy
# 1449                                                                                  Home Initiation of NiPPV
# 1454                                                                                           no intervention
# 1457                                                                                                   control
# 1458                                                                                       ventilation therapy
# 1459                                                                                  Targeting SpO2 at 93-95%
# 1460                                                                                               questionary
# 1470                                                                                              No Treatment
# 1472                                                                                          Standard of Care
# 1483                                                                                Pre-education intervention
# 1487                                                                                              Peer support
# 1489                                                                                      Sleep Advice Control
# 1505                                                                       EXASCORE to evaluated COPD severity
# 1508                                                                                 Expiratory muscle trainig
# 1518                                                        Expert-Led Sleep Disorders Screening and Treatment
# 1520                                                                                      Intermittent hypoxia
# 1527                                                                                                poligraphy
# 1534                                                                            pacemaker diagnostic algorithm
# 1538                                                                           Conservative care (control arm)
# 1544                                                                                                   Control
# 1556                                                                artificial intelligence assisted follow-up
# 1562                                                           memory evaluation at V1 and V2 (with treatment)
# 1572                                                                               Goal directed therapy (GDT)
# 1573                                                                                           Oral Appliances
# 1583                                                                                                  Sleep VS
# 1586                                                                                          Routine practice
# 1590                                                                                         Treatment of SAHS
# 1593                                                                                          Standard of Care
# 1595                                              CONV care for the diagnosis and treatment of sleep disorders
# 1596                                                                   Sleep disorders education and screening
# 1601                                                                                             Sleep hygiene
# 1603                                                                    Sleep disorder detection and treatment
# 1607                                                                                                  No strip
# 1613                                                                                         Educational video
# 1620                                                                                       Patient Observation
# 1630                                                                           FOCuSEd Integrated Intervention
# 1636                                                                                            Compressed Air
# 1640                                               Clinical follow up by general practitioners in primary care
# 1644                                                                                               Acupuncture
# 1646                                                                                                UA and RMT
# 1650                                                                                                       TCM
# 1654                                                                                              Oral Placebo
# 1656                                                                                   Stop-Bang questionnaire
# 1659                                                                                     Other supportive care
# 1666                                                                                        Pollution exposure
# 1685                                                                                              routine care
# 1696                                                                                              Disposal Aid
# 1701                                                                             Follow up in Sleep Unit Group
# 1706                                                                                                    Vivify
# 1716                                                                           health information prescription

# %%
# Step 1: Create a mapping dictionary with correct categories and their associated terms

mapping_dict = {
    'DEVICE': ['CPAP', 'PAP', 'Nasal dilator', 'full face masks'],
    'BEHAVIORAL': ['exercise', 'lifestyle', 'exercises', 'activity', 'positioning',
                   'diet', 'yoga', 'Mouth closure', 'positioning'],
    'PROCEDURE': ['SPA treatment'],
    'DIAGNOSTIC_TEST': ['Polygraphy', 'Apneascan TM', 'Polysomnography', 'PSG', 'monitor',
                        'monitoring', 'polysomnogram', 'Sleep study', 'diagnostic test'],
}

# Step 2: Replace 'OTHER' entries in the 'Interventions' column (case-insensitive)
def replace_other_entries(intervention):
    if pd.isna(intervention):  # Check for NaN
        return intervention  # Return NaN unchanged
    parts = intervention.split('|')  # Split by '|'
    for i, part in enumerate(parts):
        if 'OTHER:' in part:
            # Get the content after 'OTHER:'
            content = part.split('OTHER: ')[1].strip().lower()  # Convert content to lower case
            # Check against mapping_dict
            for category, terms in mapping_dict.items():
                for term in terms:
                    if term.lower() in content:  # Check if term (in lower case) is in the content
                        # Replace 'OTHER:' with the correct category
                        parts[i] = part.replace('OTHER:', f'{category}:')
                        break  # Exit the loop once a match is found
    return '|'.join(parts)  # Join back the parts

# Apply the replacement function
df['Interventions'] = df['Interventions'].apply(replace_other_entries)

# %%
# Extract intervention types with the pattern

import re

def extract_intervention_types(interventions_str):
    matches = re.findall(r'(\w+):', interventions_str)
    
    return list(set(matches)) # remove duplicates and return as a list

df['Intervention Types'] = df['Interventions'].apply(lambda intvs: extract_intervention_types(intvs))

# %%
# Convert the list of intervention types in each row to a single string

df['Intervention Types'] = df['Intervention Types'].apply(lambda intv_types: ', '.join(intv_types) if intv_types else '')
df['Intervention Types'].unique()
# Out:
# array(['BEHAVIORAL', 'DIETARY_SUPPLEMENT', 'DEVICE', 'DIAGNOSTIC_TEST',
#        'DRUG', 'DIETARY_SUPPLEMENT, OTHER', 'DEVICE, DRUG',
#        'DEVICE, PROCEDURE', 'DEVICE, OTHER', 'PROCEDURE',
#        'DEVICE, Device', 'OTHER, BEHAVIORAL', 'OTHER',
#        'DEVICE, OTHER, DRUG', 'DIAGNOSTIC_TEST, OTHER',
#        'PROCEDURE, BEHAVIORAL', 'DEVICE, DIETARY_SUPPLEMENT',
#        'OTHER, DRUG', 'DIETARY_SUPPLEMENT, PROCEDURE',
#        'DEVICE, DRUG, BEHAVIORAL', 'DRUG, PROCEDURE, BEHAVIORAL',
#        'DEVICE, BEHAVIORAL', 'DEVICE, DIAGNOSTIC_TEST', 'PROCEDURE, DRUG',
#        'COMBINATION_PRODUCT',
#        'DEVICE, COMBINATION_PRODUCT, PROCEDURE, BEHAVIORAL',
#        'DEVICE, COMBINATION_PRODUCT, DRUG', 'COMBINATION_PRODUCT, OTHER',
#        'DIAGNOSTIC_TEST, DRUG',
#        'COMBINATION_PRODUCT, PROCEDURE, BEHAVIORAL', '1, DRUG',
#        'DEVICE, DIETARY_SUPPLEMENT, OTHER, DRUG', 'BEHAVIORAL, DRUG',
#        'PROCEDURE, OTHER', 'DEVICE, DIAGNOSTIC_TEST, OTHER',
#        'DEVICE, DIAGNOSTIC_TEST, PROCEDURE', 'DEVICE, OTHER, BEHAVIORAL',
#        'BIOLOGICAL', 'DEVICE, DIAGNOSTIC_TEST, OTHER, BEHAVIORAL',
#        'DEVICE, PROCEDURE, OTHER', 'DRUG, BEHAVIORAL',
#        'A, C, H, DEVICE, E, F, G, B, D', 'DEVICE, BEHAVIORAL, DRUG',
#        'DEVICE, DIAGNOSTIC_TEST, BEHAVIORAL', 'DIAGNOSTIC_TEST, devices',
#        'DIAGNOSTIC_TEST, PROCEDURE, BEHAVIORAL', 'RADIATION, PROCEDURE',
#        'DIAGNOSTIC_TEST, BEHAVIORAL', 'DEVICE, PROCEDURE, DRUG',
#        'DEVICE, Europe, USA', 'DIAGNOSTIC_TEST, OTHER, DRUG',
#        'Comparator, DRUG', 'PROCEDURE, OTHER, BEHAVIORAL',
#        'DEVICE, GENETIC, DIAGNOSTIC_TEST'], dtype=object)

# %%
# Clean data with strange format

df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'Device, DEVICE' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'DEVICE, Device' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DRUG' if x == '1, DRUG' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DRUG' if x == 'DRUG, 1' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'F, A, DEVICE, D, C, H, B, G, E' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'F, A, G, B, E, D, DEVICE, H, C' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'DEVICE, D, C, E, A, F, H, G, B' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'G, DEVICE, H, A, D, E, B, F, C' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'A, C, H, DEVICE, E, F, G, B, D' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'OTHER, DEVICE' if x == 'OTHER, devices' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'USA, DEVICE, Europe' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DRUG' if x == 'Comparator, DRUG' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'Europe, DEVICE, USA' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'Europe, USA, DEVICE' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DEVICE' if x == 'DEVICE, Europe, USA' else x)
df['Intervention Types'] = df['Intervention Types'].apply(lambda x: 'DIAGNOSTIC_TEST, DEVICE' if x == 'DIAGNOSTIC_TEST, devices' else x)

# %%
df['Intervention Types'].unique()
# Out:
# array(['BEHAVIORAL', 'DIETARY_SUPPLEMENT', 'DEVICE', 'DIAGNOSTIC_TEST',
#        'DRUG', 'DIETARY_SUPPLEMENT, OTHER', 'DEVICE, DRUG',
#        'DEVICE, PROCEDURE', 'DEVICE, OTHER', 'PROCEDURE',
#        'OTHER, BEHAVIORAL', 'OTHER', 'DEVICE, OTHER, DRUG',
#        'DIAGNOSTIC_TEST, OTHER', 'PROCEDURE, BEHAVIORAL',
#        'DEVICE, DIETARY_SUPPLEMENT', 'OTHER, DRUG',
#        'DIETARY_SUPPLEMENT, PROCEDURE', 'DEVICE, DRUG, BEHAVIORAL',
#        'DRUG, PROCEDURE, BEHAVIORAL', 'DEVICE, BEHAVIORAL',
#        'DEVICE, DIAGNOSTIC_TEST', 'PROCEDURE, DRUG',
#        'COMBINATION_PRODUCT',
#        'DEVICE, COMBINATION_PRODUCT, PROCEDURE, BEHAVIORAL',
#        'DEVICE, COMBINATION_PRODUCT, DRUG', 'COMBINATION_PRODUCT, OTHER',
#        'DIAGNOSTIC_TEST, DRUG',
#        'COMBINATION_PRODUCT, PROCEDURE, BEHAVIORAL',
#        'DEVICE, DIETARY_SUPPLEMENT, OTHER, DRUG', 'BEHAVIORAL, DRUG',
#        'PROCEDURE, OTHER', 'DEVICE, DIAGNOSTIC_TEST, OTHER',
#        'DEVICE, DIAGNOSTIC_TEST, PROCEDURE', 'DEVICE, OTHER, BEHAVIORAL',
#        'BIOLOGICAL', 'DEVICE, DIAGNOSTIC_TEST, OTHER, BEHAVIORAL',
#        'DEVICE, PROCEDURE, OTHER', 'DRUG, BEHAVIORAL',
#        'DEVICE, BEHAVIORAL, DRUG', 'DEVICE, DIAGNOSTIC_TEST, BEHAVIORAL',
#        'DIAGNOSTIC_TEST, DEVICE',
#        'DIAGNOSTIC_TEST, PROCEDURE, BEHAVIORAL', 'RADIATION, PROCEDURE',
#        'DIAGNOSTIC_TEST, BEHAVIORAL', 'DEVICE, PROCEDURE, DRUG',
#        'DIAGNOSTIC_TEST, OTHER, DRUG', 'PROCEDURE, OTHER, BEHAVIORAL',
#        'DEVICE, GENETIC, DIAGNOSTIC_TEST'], dtype=object)

# %%
intv_types_exploded = df['Intervention Types'].str.split(', ').explode()
intv_types_counts = intv_types_exploded.value_counts(ascending=False)

print(intv_types_counts) # clinical trials numbers for each interverence
# Out:
# Intervention Types
# DEVICE                 919
# DRUG                   309
# OTHER                  246
# BEHAVIORAL             222
# PROCEDURE              168
# DIAGNOSTIC_TEST         88
# DIETARY_SUPPLEMENT      12
# COMBINATION_PRODUCT      6
# BIOLOGICAL               3
# RADIATION                1
# GENETIC                  1
# Name: count, dtype: int64

# %%
# import os

# path = os.path.join('/Users/ellia.hsieh/Documents/GitHub/strategic-partner-identification/data/02-processed', 'processed-sleep-apnea-1.csv')
# df.to_csv(path, index=False)
